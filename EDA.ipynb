# %%
                         #<EXPLORATORY DATA ANALYSIS ON A DATASET>
#  <DATA CLEANING AN DPREPARATIONS>
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#lOADING DATA
df=pd.read_csv(r"C:\Users\sms2v\OneDrive\Desktop\Data Science\DS assignments\5.EDA1\EDA1\Cardiotocographic.csv")

# %%
#No. of null values in each column
print(df.isnull().sum())
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
#Imputation i.e., filling the blanks with the mean value of the columns

# %%
df["LB"].fillna(df["LB"].mean(),inplace=True)
df["AC"].fillna(df["AC"].mean(),inplace=True)
df["DS"].fillna(df["DS"].mean(),inplace=True)
df["DP"].fillna(df["DP"].mean(),inplace=True)
df["MLTV"].fillna(df["MLTV"].mean(),inplace=True)
df["Width"].fillna(df["Width"].mean(),inplace=True)
df["Tendency"].fillna(df["Tendency"].mean(),inplace=True)
df["NSP"].fillna(df["NSP"].mean(),inplace=True)
# Out:
# C:\Users\sms2v\AppData\Local\Temp\ipykernel_14496\3070156179.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["LB"].fillna(df["LB"].mean(),inplace=True)
# C:\Users\sms2v\AppData\Local\Temp\ipykernel_14496\3070156179.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
#Now there are no null values
print(df.isnull().sum())
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
print(df.dtypes)
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
 #  <STATISTICAL SUMMARY>

# %%
print("Statistical summary for each variable:")
df.describe()
# Out:
# Statistical summary for each variable:
#                 LB           AC           FM           UC           DL  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.214328     0.004370     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001668     0.000000     0.004484     0.000000
# 75%     140.000000     0.005606     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000141     0.000836    18.813973     1.173632    21.205041
# ...

# %%
#  <Interquertile range for "LB" >
q1=np.percentile(df["LB"],25)
q3=np.percentile(df["LB"],75)
IQR=q3-q1
IQR
# Out:
# np.float64(14.0)

# %%
#  <Interquertile range for "AC" >
q1=np.percentile(df["AC"],25)
q3=np.percentile(df["AC"],75)
IQR=q3-q1
IQR
# Out:
# np.float64(0.0056061275)

# %%
#  <Interquertile range for "FM" >
q1=np.percentile(df["FM"],25)
q3=np.percentile(df["FM"],75)
IQR=q3-q1
IQR
# Out:
# np.float64(0.00256657125)

# %%
#  <Interquertile range for "UC" >
q1=np.percentile(df["UC"],25)
q3=np.percentile(df["UC"],75)
IQR=q3-q1
IQR
# Out:
# np.float64(0.004685357249999999)

# %%
#  <Interquertile range for "DL" >
q1=np.percentile(df["DL"],25)
q3=np.percentile(df["DL"],75)
IQR=q3-q1
IQR
# Out:
# np.float64(0.003289474)

# %%
#  <Interquertile range for "DS" >
q1=np.percentile(df["DS"],25)
q3=np.percentile(df["DS"],75)
IQR=q3-q1
IQR
# Out:
# np.float64(0.0)

# %%
#  <Interquertile range for "ASTV" >
q1=np.percentile(df["ASTV"],25)
q3=np.percentile(df["ASTV"],75)
IQR=q3-q1
IQR
# Out:
# np.float64(29.0)

# %%
#  <Interquertile range for "MSTV" >
q1=np.percentile(df["MSTV"],25)
q3=np.percentile(df["MSTV"],75)
IQR=q3-q1
IQR
# Out:
# np.float64(1.0)

# %%
#  <Interquertile range for "ALTV" >
q1=np.percentile(df["ALTV"],25)
q3=np.percentile(df["ALTV"],75)
IQR=q3-q1
IQR
# Out:
# np.float64(11.0)

# %%
#  <Interquertile range for "MLTV" >
q1=np.percentile(df["MLTV"],25)
q3=np.percentile(df["MLTV"],75)
IQR=q3-q1
IQR
# Out:
# np.float64(6.200000000000001)

# %%
#  <Interquertile range for "Width" >
q1=np.percentile(df["Width"],25)
q3=np.percentile(df["Width"],75)
IQR=q3-q1
IQR
# Out:
# np.float64(63.0)

# %%
#  <Interquertile range for "Tendency" >
q1=np.percentile(df["Tendency"],25)
q3=np.percentile(df["Tendency"],75)
IQR=q3-q1
IQR
# Out:
# np.float64(1.0)

# %%
#  <Interquertile range for "NSP" >
q1=np.percentile(df["NSP"],25)
q3=np.percentile(df["NSP"],75)
IQR=q3-q1
IQR
# Out:
# np.float64(0.0)

# %%
# <Data Visuvalization>
#  <Boxplot vizualization>
#  <Detecting and treating outliers>

# %%
df["AC"].plot(kind="box",vert=False)
print("Skeweness:",df["AC"].skew())     
q1=np.percentile(df["AC"],25)
q3=np.percentile(df["AC"],75)
IQR=q3-q1
UW=q3+1.5*IQR
LW=q3-1.5*IQR
print("No. of Outliers in AC:",len(df[df["AC"]>UW])+len(df[df["AC"]<LW]))
# Out:
# Skeweness: 2.026327623148809
# No. of Outliers in AC: 43

# %%
df["AC"][df["AC"]>UW]=UW
df["AC"][df["AC"]<LW]=LW
df["AC"].plot(kind="box",vert=False)
# Out:
# <Axes: >

# %%
df["FM"].plot(kind="box",vert=False)
print("Skeweness:",df["FM"].skew())     
q1=np.percentile(df["FM"],25)
q3=np.percentile(df["FM"],75)
IQR=q3-q1
UW=q3+1.5*IQR
LW=q3-1.5*IQR
print("No. of Outliers in FM:",len(df[df["FM"]>UW])+len(df[df["FM"]<LW]))
# Out:
# Skeweness: 6.75306980198638
# No. of Outliers in FM: 359

# %%
df["FM"][df["FM"]>UW]=UW
df["FM"][df["FM"]<LW]=LW
df["FM"].plot(kind="box",vert=False)
# Out:
# <Axes: >

# %%
df["UC"].plot(kind="box",vert=False)
print("Skeweness:",df["UC"].skew())     
q1=np.percentile(df["UC"],25)
q3=np.percentile(df["UC"],75)
IQR=q3-q1
UW=q3+1.5*IQR
LW=q3-1.5*IQR
print("No. of Outliers in UC:",len(df[df["UC"]>UW])+len(df[df["UC"]<LW]))
# Out:
# Skeweness: 0.9742394510625922
# No. of Outliers in UC: 13

# %%
df["UC"][df["UC"]>UW]=UW
df["UC"][df["UC"]<LW]=LW
df["UC"].plot(kind="box",vert=False)
# Out:
# <Axes: >

# %%
df["DL"].plot(kind="box",vert=False)
print("Skeweness:",df["DL"].skew())     
q1=np.percentile(df["DL"],25)
q3=np.percentile(df["DL"],75)
IQR=q3-q1
UW=q3+1.5*IQR
LW=q3-1.5*IQR
print("No. of Outliers in DL:",len(df[df["DL"]>UW])+len(df[df["DL"]<LW]))
# Out:
# Skeweness: 2.0103895349327043
# No. of Outliers in DL: 125

# %%
df["DL"][df["DL"]>UW]=UW
df["DL"][df["DL"]<LW]=LW
df["DL"].plot(kind="box",vert=False)
# Out:
# <Axes: >

# %%
df["DS"].plot(kind="box",vert=False)
print("Skeweness:",df["DS"].skew())     
q1=np.percentile(df["DS"],25)
q3=np.percentile(df["DS"],75)
IQR=q3-q1
UW=q3+1.5*IQR
LW=q3-1.5*IQR
print("No. of Outliers in DS:",len(df[df["DS"]>UW])+len(df[df["DS"]<LW]))
# Out:
# Skeweness: 8.460815415823722
# No. of Outliers in DS: 141

# %%
df["DS"][df["DS"]>UW]=UW
df["DS"][df["DS"]<LW]=LW
df["DS"].plot(kind="box",vert=False)
# Out:
# <Axes: >

# %%
df["DP"].plot(kind="box",vert=False)
print("Skeweness:",df["DP"].skew())     
q1=np.percentile(df["DP"],25)
q3=np.percentile(df["DP"],75)
IQR=q3-q1
UW=q3+1.5*IQR
LW=q3-1.5*IQR
print("No. of Outliers in DP:",len(df[df["DP"]>UW])+len(df[df["DP"]<LW]))
# Out:
# Skeweness: 6.45437733778733
# No. of Outliers in DP: 305

# %%
df["DP"][df["DP"]>UW]=UW
df["DP"][df["DP"]<LW]=LW
df["DP"].plot(kind="box",vert=False)
# Out:
# <Axes: >

# %%
df["ASTV"].plot(kind="box",vert=False)
print("Skeweness:",df["ASTV"].skew())     
q1=np.percentile(df["ASTV"],25)
q3=np.percentile(df["ASTV"],75)
IQR=q3-q1
UW=q3+1.5*IQR
LW=q3-1.5*IQR
print("No. of Outliers in ASTV:",len(df[df["ASTV"]>UW])+len(df[df["ASTV"]<LW]))
# Out:
# Skeweness: 0.055871676734938334
# No. of Outliers in ASTV: 52

# %%
df["ASTV"][df["ASTV"]>UW]=UW
df["ASTV"][df["ASTV"]<LW]=LW
df["ASTV"].plot(kind="box",vert=False)
# Out:
# <Axes: >

# %%
df["MSTV"].plot(kind="box",vert=False)
print("Skeweness:",df["MSTV"].skew())     
q1=np.percentile(df["MSTV"],25)
q3=np.percentile(df["MSTV"],75)
IQR=q3-q1
UW=q3+1.5*IQR
LW=q3-1.5*IQR
print("No. of Outliers in MSTV:",len(df[df["MSTV"]>UW])+len(df[df["MSTV"]<LW]))
# Out:
# Skeweness: 4.14251826362969
# No. of Outliers in MSTV: 80

# %%
df["MSTV"][df["MSTV"]>UW]=UW
df["MSTV"][df["MSTV"]<LW]=LW
df["MSTV"].plot(kind="box",vert=False)
# Out:
# <Axes: >

# %%
df["ALTV"].plot(kind="box",vert=False)
print("Skeweness:",df["ALTV"].skew())     
q1=np.percentile(df["ALTV"],25)
q3=np.percentile(df["ALTV"],75)
IQR=q3-q1
UW=q3+1.5*IQR
LW=q3-1.5*IQR
print("No. of Outliers in ALTV:",len(df[df["ALTV"]>UW])+len(df[df["ALTV"]<LW]))
# Out:
# Skeweness: 2.9811987992454214
# No. of Outliers in ALTV: 318

# %%
df["ALTV"][df["ALTV"]>UW]=UW
df["ALTV"][df["ALTV"]<LW]=LW
df["ALTV"].plot(kind="box",vert=False)
# Out:
# <Axes: >

# %%
df["MLTV"].plot(kind="box",vert=False)
print("Skeweness:",df["MLTV"].skew())     
q1=np.percentile(df["MLTV"],25)
q3=np.percentile(df["MLTV"],75)
IQR=q3-q1
UW=q3+1.5*IQR
LW=q3-1.5*IQR
print("No. of Outliers in MLTV:",len(df[df["MLTV"]>UW])+len(df[df["MLTV"]<LW]))
# Out:
# Skeweness: 3.5590443611232834
# No. of Outliers in MLTV: 295

# %%
df["MLTV"][df["MLTV"]>UW]=UW
df["MLTV"][df["MLTV"]<LW]=LW
df["MLTV"].plot(kind="box",vert=False)
# Out:
# <Axes: >

# %%
df["Width"].plot(kind="box",vert=False)
print("Skeweness:",df["Width"].skew())     
q1=np.percentile(df["Width"],25)
q3=np.percentile(df["Width"],75)
IQR=q3-q1
UW=q3+1.5*IQR
LW=q3-1.5*IQR
print("No. of Outliers in Width:",len(df[df["Width"]>UW])+len(df[df["Width"]<LW]))
# Out:
# Skeweness: 0.49770712821363794
# No. of Outliers in Width: 14

# %%
df["Width"][df["Width"]>UW]=UW
df["Width"][df["Width"]<LW]=LW
df["Width"].plot(kind="box",vert=False)
# Out:
# <Axes: >

# %%
df["Tendency"].plot(kind="box",vert=False)
print("Skeweness:",df["Tendency"].skew())     
q1=np.percentile(df["Tendency"],25)
q3=np.percentile(df["Tendency"],75)
IQR=q3-q1
UW=q3+1.5*IQR
LW=q3-1.5*IQR
print("No. of Outliers in Tendency:",len(df[df["Tendency"]>UW])+len(df[df["Tendency"]<LW]))
# Out:
# Skeweness: -0.49925695065390857
# No. of Outliers in Tendency: 173

# %%
df["Tendency"][df["Tendency"]>UW]=UW
df["Tendency"][df["Tendency"]<LW]=LW
df["Tendency"].plot(kind="box",vert=False)
# Out:
# <Axes: >

# %%
df["NSP"].plot(kind="box",vert=False)
print("Skeweness:",df["NSP"].skew())     
q1=np.percentile(df["NSP"],25)
q3=np.percentile(df["NSP"],75)
IQR=q3-q1
UW=q3+1.5*IQR
LW=q3-1.5*IQR
print("No. of Outliers in NSP:",len(df[df["NSP"]>UW])+len(df[df["NSP"]<LW]))
# Out:
# Skeweness: 1.8198980495501753
# No. of Outliers in NSP: 580

# %%
df["NSP"][df["NSP"]>UW]=UW
df["NSP"][df["NSP"]<LW]=LW
df["NSP"].plot(kind="box",vert=False)
# Out:
# <Axes: >

# %%
                          #  <Scatter plot>

# %%
#Scatter plot between AC and FM
plt.scatter(df["AC"],df["FM"],color="purple")

# %%
#Scatter plot between UC and DL
plt.scatter(df["UC"],df["DL"],color="red")

# %%
#Scatter plot between ASTV and MATV
plt.scatter(df["ASTV"],df["MSTV"],color="green")

# %%
#Scatter plot between ALTV and MLTV
plt.scatter(df["ALTV"],df["MLTV"],color="pink")

# %%
#Scatter plot between Width and Tendency
plt.scatter(df["Width"],df["Tendency"],color="green")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2126 non-null   float64
#  1   AC        2126 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2126 non-null   float64
#  6   DP        2126 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2126 non-null   float64
#  11  Width     2126 non-null   float64
#  12  Tendency  2126 non-null   float64
#  13  NSP       2126 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
# and Correlation Heatmaps
plt.figure(figsize=(10, 8))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
#Pie charts for some numerical vallues
df1=['LB','AC','Width','Tendency',"ALTV"]
for var in df1:
    plt.figure(figsize=(10,8))
    df[var].value_counts().plot(kind='pie',startangle=90)
    plt.title(f'pie Chart of {var}')
    plt.ylabel('')  # remove y-axis label
    plt.show()

# %%
                      #<Pair plots>
import seaborn as sns
sns.pairplot(df[["LB","FM","UC","DL","DS"]])
plt.show()

# %%
#4.Pattern Recognition and Insights:
Strong_Correlation=correlation_matrix[(correlation_matrix>0.5) & (correlation_matrix<1)]
print('strong correlations:')
Strong_Correlation
# Out:
# strong correlations:
#           LB  AC  FM  UC        DL  DS  DP  ASTV      MSTV  ALTV  MLTV  \
# LB       NaN NaN NaN NaN       NaN NaN NaN   NaN       NaN   NaN   NaN
# AC       NaN NaN NaN NaN       NaN NaN NaN   NaN       NaN   NaN   NaN
# FM       NaN NaN NaN NaN       NaN NaN NaN   NaN       NaN   NaN   NaN
# UC       NaN NaN NaN NaN       NaN NaN NaN   NaN       NaN   NaN   NaN
# DL       NaN NaN NaN NaN       NaN NaN NaN   NaN  0.572219   NaN   NaN
# DS       NaN NaN NaN NaN       NaN NaN NaN   NaN       NaN   NaN   NaN
# DP       NaN NaN NaN NaN       NaN NaN NaN   NaN       NaN   NaN   NaN
# ASTV     NaN NaN NaN NaN       NaN NaN NaN   NaN       NaN   NaN   NaN
# MSTV     NaN NaN NaN NaN  0.572219 NaN NaN   NaN       NaN   NaN   NaN
# ALTV     NaN NaN NaN NaN       NaN NaN NaN   NaN       NaN   NaN   NaN
# MLTV     NaN NaN NaN NaN       NaN NaN NaN   NaN       NaN   NaN   NaN
# Width    NaN NaN NaN NaN  0.520767 NaN NaN   NaN  0.654720   NaN   NaN
# ...

# %%
                      #<Conclusion>
#In the given dataset the null values are replaced by the mean of their respective variable.
#The outliers are found and treated byr IQR method.
#identified the relation between variables by correlation matrics
#Heat maps used to see the relation between variables.
#There is not much correlation between variables apart some few.
